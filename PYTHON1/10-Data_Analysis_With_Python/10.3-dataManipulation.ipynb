# %% [markdown]
# ### Data Manipulation and Analysis with Pandas
#
# Data manipulation and analysis are key tasks in any data science or data analysis project.
# Pandas provides a wide range of functions for data manipulation and analysis, making it easier to cean, transform, and extract insights from data.

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
## Fetch the first 5 rows
df.head(5)
# Out:
#          Date     Category   Product  Sales_Value   Region
# 0  2025-04-23     Clothing       NaN     30676.31      NaN
# 1  2025-10-04       Sports  Football     17909.51    South
# 2  2025-06-01  Electronics       NaN      6136.06    South
# 3  2025-04-04       Sports       NaN     35204.68     West
# 4  2025-07-29    Furniture       Bed     44949.44  Central

# %%
df.tail(5)
# Out:
#           Date         Category  Product  Sales_Value Region
# 45  2025-08-21           Beauty  Shampoo     19067.24   East
# 46         NaN              NaN  Toaster     48666.25   West
# 47  2025-02-02  Home Appliances  Blender     21059.20   East
# 48  2025-08-09         Clothing    Jeans     32251.62   West
# 49  2025-09-15           Beauty   Lotion     27292.32    NaN

# %%
df.describe()
# Out:
#         Sales_Value
# count     45.000000
# mean   24409.550222
# std    14346.372850
# min      646.270000
# 25%    13304.030000
# 50%    24422.470000
# 75%    35204.680000
# max    49804.360000

# %%
df.dtypes
# Out:
# Date            object
# Category        object
# Product         object
# Sales_Value    float64
# Region          object
# dtype: object

# %%
# Handling Missing Values
df.isnull().any()
# Out:
# Date           True
# Category       True
# Product        True
# Sales_Value    True
# Region         True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Date           5
# Category       5
# Product        5
# Sales_Value    5
# Region         5
# dtype: int64

# %%
df_filled = df.fillna(0) # It will replace to zero in missing values

# %%
# Filling missing values with the mean of the column

df['Sales_fillNA'] = df['Sales_Value'].fillna(df['Sales_Value'].mean())
df
# Out:
#           Date         Category     Product  Sales_Value   Region  \
# 0   2025-04-23         Clothing         NaN     30676.31      NaN
# 1   2025-10-04           Sports    Football     17909.51    South
# 2   2025-06-01      Electronics         NaN      6136.06    South
# 3   2025-04-04           Sports         NaN     35204.68     West
# 4   2025-07-29        Furniture         Bed     44949.44  Central
# 5          NaN           Sports  Gym Gloves     23237.92      NaN
# 6   2025-08-30         Clothing       Dress     16813.32    North
# 7   2025-01-16              NaN       Cream     29586.63  Central
# 8   2025-10-05         Clothing     T-shirt          NaN      NaN
# 9   2025-08-24           Beauty     Perfume      7895.92      NaN
# 10  2025-01-08              NaN         NaN      6839.39     East
# 11  2025-01-26      Electronics      Camera     47858.71  Central
# 12  2025-04-27           Beauty     Shampoo     25948.33    South
# 13  2025-01-08           Beauty         NaN     11794.26    South
# 14  2025-09-24      Electronics      Tablet          NaN  Central
# 15  2025-08-31      Electronics      Tablet      5522.74    South
# 16  2025-04-18        Furniture         Bed      9880.09     West
# 17  2025-03-22         Clothing      Jacket     26298.10     East
# 18  2025-01-15        Furniture       Table          NaN    South
# 19  2025-06-23           Beauty     Shampoo     17911.24     West
# 20  2025-01-09      Electronics      Camera     43073.84     West
# 21  2025-08-12           Beauty       Cream     28684.18  Central
# 22  2025-09-28              NaN       Chair      7848.22    North
# 23  2025-04-07           Beauty    Lipstick     41711.99  Central
# 24  2025-09-07        Furniture         Bed     18993.70     East
# 25  2025-01-21        Furniture        Sofa     14000.80    North
# 26  2025-03-24         Clothing      Jacket          NaN  Central
# 27  2025-09-24      Electronics      Tablet     24422.47    South
# 28         NaN  Home Appliances     Toaster     30564.76     East
# 29  2025-04-08         Clothing       Jeans     42905.48  Central
# 30         NaN  Home Appliances     Toaster     49804.36    North
# 31  2025-02-10      Electronics      Tablet     38870.51  Central
# 32  2025-07-15        Furniture    Cupboard     13304.03    North
# 33  2025-10-01           Sports  Gym Gloves      6351.91    South
# 34  2025-04-29              NaN      Camera     25889.90     West
# 35  2025-08-18        Furniture       Chair       646.27    South
# 36  2025-07-20      Electronics      Laptop     45098.69  Central
# 37  2025-04-02           Beauty       Cream     48706.42    South
# 38  2025-10-05        Furniture       Chair          NaN     West
# 39  2025-04-14  Home Appliances        Iron     17205.58  Central
# 40         NaN      Electronics      Camera     36798.54    South
# 41  2025-06-07        Furniture       Table      6030.02  Central
# 42  2025-05-23           Beauty      Lotion     17146.93     West
# 43  2025-09-03           Sports  Gym Gloves      2749.21     East
# 44  2025-02-05      Electronics      Tablet     24822.67     East
# 45  2025-08-21           Beauty     Shampoo     19067.24     East
# 46         NaN              NaN     Toaster     48666.25     West
# 47  2025-02-02  Home Appliances     Blender     21059.20     East
# 48  2025-08-09         Clothing       Jeans     32251.62     West
# 49  2025-09-15           Beauty      Lotion     27292.32      NaN
#
#     Sales_fillNA
# 0   30676.310000
# 1   17909.510000
# 2    6136.060000
# 3   35204.680000
# 4   44949.440000
# 5   23237.920000
# 6   16813.320000
# 7   29586.630000
# 8   24409.550222
# 9    7895.920000
# 10   6839.390000
# 11  47858.710000
# 12  25948.330000
# 13  11794.260000
# 14  24409.550222
# 15   5522.740000
# 16   9880.090000
# 17  26298.100000
# 18  24409.550222
# 19  17911.240000
# 20  43073.840000
# 21  28684.180000
# 22   7848.220000
# 23  41711.990000
# 24  18993.700000
# 25  14000.800000
# 26  24409.550222
# 27  24422.470000
# 28  30564.760000
# 29  42905.480000
# 30  49804.360000
# 31  38870.510000
# 32  13304.030000
# 33   6351.910000
# 34  25889.900000
# 35    646.270000
# 36  45098.690000
# 37  48706.420000
# 38  24409.550222
# 39  17205.580000
# 40  36798.540000
# 41   6030.020000
# 42  17146.930000
# 43   2749.210000
# 44  24822.670000
# 45  19067.240000
# 46  48666.250000
# 47  21059.200000
# 48  32251.620000
# 49  27292.320000

# %%
df.dtypes
# Out:
# Date             object
# Category         object
# Product          object
# Sales_Value     float64
# Region           object
# Sales_fillNA    float64
# dtype: object

# %%
# Renaming Columns

df = df.rename(columns={'Date' : 'Sale_Date'})
df.head()
# Out:
#     Sale_Date     Category   Product  Sales_Value   Region  Sales_fillNA
# 0  2025-04-23     Clothing       NaN     30676.31      NaN      30676.31
# 1  2025-10-04       Sports  Football     17909.51    South      17909.51
# 2  2025-06-01  Electronics       NaN      6136.06    South       6136.06
# 3  2025-04-04       Sports       NaN     35204.68     West      35204.68
# 4  2025-07-29    Furniture       Bed     44949.44  Central      44949.44

# %%
# Change Datatypes

# Replace missing values in 'Sales_Value' with the column's mean,
# convert all values to integers, and store in a new column 'Value_new'
df['Value_new'] = df['Sales_Value'].fillna(df['Sales_Value'].mean()).astype(int)

# Show first 5 rows to verify changes
df.head()
# Out:
#     Sale_Date     Category   Product  Sales_Value   Region  Sales_fillNA  \
# 0  2025-04-23     Clothing       NaN     30676.31      NaN      30676.31
# 1  2025-10-04       Sports  Football     17909.51    South      17909.51
# 2  2025-06-01  Electronics       NaN      6136.06    South       6136.06
# 3  2025-04-04       Sports       NaN     35204.68     West      35204.68
# 4  2025-07-29    Furniture       Bed     44949.44  Central      44949.44
#
#    Value_new
# 0      30676
# 1      17909
# 2       6136
# 3      35204
# 4      44949

# %%
# Create a new column 'New_Product' by applying a function to each value in 'Product'
# The lambda function duplicates each product name (e.g., "Laptop" → "LaptopLaptop")
df['New_Product'] = df['Product'].apply(lambda x: x * 2)

# Display first 5 rows to see the result
df.head()
# Out:
#     Sale_Date     Category   Product  Sales_Value   Region  Sales_fillNA  \
# 0  2025-04-23     Clothing       NaN     30676.31      NaN      30676.31
# 1  2025-10-04       Sports  Football     17909.51    South      17909.51
# 2  2025-06-01  Electronics       NaN      6136.06    South       6136.06
# 3  2025-04-04       Sports       NaN     35204.68     West      35204.68
# 4  2025-07-29    Furniture       Bed     44949.44  Central      44949.44
#
#    Value_new       New_Product
# 0      30676               NaN
# 1      17909  FootballFootball
# 2       6136               NaN
# 3      35204               NaN
# 4      44949            BedBed

# %% [markdown]
# #### Data Aggregating and Grouping

# %%
df.head()
# Out:
#     Sale_Date     Category   Product  Sales_Value   Region  Sales_fillNA  \
# 0  2025-04-23     Clothing       NaN     30676.31      NaN      30676.31
# 1  2025-10-04       Sports  Football     17909.51    South      17909.51
# 2  2025-06-01  Electronics       NaN      6136.06    South       6136.06
# 3  2025-04-04       Sports       NaN     35204.68     West      35204.68
# 4  2025-07-29    Furniture       Bed     44949.44  Central      44949.44
#
#    Value_new       New_Product
# 0      30676               NaN
# 1      17909  FootballFootball
# 2       6136               NaN
# 3      35204               NaN
# 4      44949            BedBed

# %%
# Group the DataFrame rows based on unique 'Product' names and calculate the average (mean) of 'Sales_Value' for each product group
grouped_mean = df.groupby('Product')['Sales_Value'].mean()

print(grouped_mean)
# Out:
# Product
# Bed           24607.743333
# Blender       21059.200000
# Camera        38405.247500
# Chair          4247.245000
# Cream         35659.076667
# Cupboard      13304.030000
# Dress         16813.320000
# Football      17909.510000
# Gym Gloves    10779.680000
# Iron          17205.580000
# Jacket        26298.100000
# Jeans         37578.550000
# Laptop        45098.690000
# Lipstick      41711.990000
# Lotion        22219.625000
# Perfume        7895.920000
# Shampoo       20975.603333
# Sofa          14000.800000
# T-shirt                NaN
# Table          6030.020000
# Tablet        23409.597500
# Toaster       43011.790000
# Name: Sales_Value, dtype: float64

# %%
grouped_sum = df.groupby(['Product', 'Region'])['Sales_Value'].sum()
print(grouped_sum)
# Out:
# Product     Region
# Bed         Central    44949.44
#             East       18993.70
#             West        9880.09
# Blender     East       21059.20
# Camera      Central    47858.71
#             South      36798.54
#             West       68963.74
# Chair       North       7848.22
#             South        646.27
#             West           0.00
# Cream       Central    58270.81
#             South      48706.42
# Cupboard    North      13304.03
# Dress       North      16813.32
# Football    South      17909.51
# Gym Gloves  East        2749.21
#             South       6351.91
# Iron        Central    17205.58
# Jacket      Central        0.00
#             East       26298.10
# Jeans       Central    42905.48
#             West       32251.62
# Laptop      Central    45098.69
# Lipstick    Central    41711.99
# Lotion      West       17146.93
# Shampoo     East       19067.24
#             South      25948.33
#             West       17911.24
# Sofa        North      14000.80
# Table       Central     6030.02
#             South          0.00
# Tablet      Central    38870.51
#             East       24822.67
#             South      29945.21
# Toaster     East       30564.76
#             North      49804.36
#             West       48666.25
# Name: Sales_Value, dtype: float64

# %%
df.groupby(['Product', 'Region'])['Sales_Value'].mean()
# Out:
# Product     Region
# Bed         Central    44949.440
#             East       18993.700
#             West        9880.090
# Blender     East       21059.200
# Camera      Central    47858.710
#             South      36798.540
#             West       34481.870
# Chair       North       7848.220
#             South        646.270
#             West             NaN
# Cream       Central    29135.405
#             South      48706.420
# Cupboard    North      13304.030
# Dress       North      16813.320
# Football    South      17909.510
# Gym Gloves  East        2749.210
#             South       6351.910
# Iron        Central    17205.580
# Jacket      Central          NaN
#             East       26298.100
# Jeans       Central    42905.480
#             West       32251.620
# Laptop      Central    45098.690
# Lipstick    Central    41711.990
# Lotion      West       17146.930
# Shampoo     East       19067.240
#             South      25948.330
#             West       17911.240
# Sofa        North      14000.800
# Table       Central     6030.020
#             South            NaN
# Tablet      Central    38870.510
#             East       24822.670
#             South      14972.605
# Toaster     East       30564.760
#             North      49804.360
#             West       48666.250
# Name: Sales_Value, dtype: float64

# %%
# Aggregate multiple functions

grouped_agg = df.groupby('Region')['Sales_Value'].agg(['mean', 'sum', 'count'])
grouped_agg
# Out:
#                 mean        sum  count
# Region
# Central  34290.12300  342901.23     10
# East     18799.28375  150394.27      8
# North    20354.14600  101770.73      5
# South    18423.65100  184236.51     10
# West     28753.06875  230024.55      8

# %%
# Merging and joining Dataframes
# Create sample Dataframes

df1 = pd.DataFrame({'Key' : ['A', 'B', 'C'], 'Value1' : [1, 2, 3]})
df2 = pd.DataFrame({'Key' : ['A', 'B', 'D'], 'Value1' : [4, 5, 6]})

# %%
df1
# Out:
#   Key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   Key  Value1
# 0   A       4
# 1   B       5
# 2   D       6

# %%
# Merge DataFrame on the 'Key Columns'
pd.merge(df1, df2, on = "Key", how = "inner")

# pd.merge() → function used to combine two DataFrames.
# df1, df2 → the two DataFrames being merged.
# on="Key" → specifies the common column ('Key') used for matching rows.
# how="inner" → performs an inner join, meaning only rows with matching 'Key' values in both DataFrames will be included in the result.
# Out:
#   Key  Value1_x  Value1_y
# 0   A         1         4
# 1   B         2         5

# %%
pd.merge(df1, df2, on = "Key", how = "outer")
# Out:
#   Key  Value1_x  Value1_y
# 0   A       1.0       4.0
# 1   B       2.0       5.0
# 2   C       3.0       NaN
# 3   D       NaN       6.0

# %%
pd.merge(df1, df2, on = "Key", how = "left")
# Out:
#   Key  Value1_x  Value1_y
# 0   A         1       4.0
# 1   B         2       5.0
# 2   C         3       NaN

# %%
pd.merge(df1, df2, on = "Key", how = "right")
# Out:
#   Key  Value1_x  Value1_y
# 0   A       1.0         4
# 1   B       2.0         5
# 2   D       NaN         6
