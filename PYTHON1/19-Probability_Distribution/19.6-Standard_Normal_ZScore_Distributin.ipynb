# %% [markdown]
# # 📘 Standard Normal Distribution and Z-Score
# ## 1️⃣ Introduction to Standard Normal Distribution
#
# In statistics, the **Standard Normal Distribution (SND)** is a special case of the **normal distribution**.
#
# It is a continuous probability distribution where:
# - Mean (μ) = 0
# - Standard Deviation (σ) = 1
#
# This distribution is widely used to **standardize data** and compare values from different datasets.
#
# ## 2️⃣ Normal Distribution Recap
#
# A normal distribution is defined by two parameters:
# - Mean (μ)
# - Standard deviation (σ)
#
# Example dataset from notes:
# X = {1, 2, 3, 4, 5}
# μ = 3
# σ ≈ 1.414
#
# The graph is bell-shaped and symmetric around the mean.
#
# ## 3️⃣ Standard Normal Distribution (SND)
# A **standard normal distribution** is a normal distribution that has been transformed so that:
# μ = 0
# σ = 1
#
# Notation:
# X ~ N(0, 1)
#
# This transformation allows easier probability calculation and comparison.
#
# ## 4️⃣ Z-Score
# A **Z-score** represents **how many standard deviations a value is away from the mean**.
#
# It converts any normal distribution into a **standard normal distribution**.
#
# ## 5️⃣ Z-Score Formula
# Z = (xᵢ − μ) / σ
#
# Where:
# - xᵢ = data value
# - μ = mean
# - σ = standard deviation
#
# ## 6️⃣ Example: Converting Data to Z-Scores
#
# Given:
# X = {1, 2, 3, 4, 5}
# μ = 3
# σ = 1
#
# Compute Z-scores:
#
# Z(1) = (1 − 3) / 1 = −2
# Z(2) = (2 − 3) / 1 = −1
# Z(3) = (3 − 3) / 1 = 0
# Z(4) = (4 − 3) / 1 = 1
# Z(5) = (5 − 3) / 1 = 2
#
# So,
# Z = {−2, −1, 0, 1, 2}
#
# This matches the transformation shown in the notes.
#
# ## 7️⃣ Interpretation of Z-Score
#
# - Z = 0 → value is exactly at the mean
# - Z > 0 → value is above the mean
# - Z < 0 → value is below the mean
# - Larger |Z| → farther from the mean
#
# ## 8️⃣ Example: Distance from the Mean
# ### Example 1
# μ = 4
# σ = 1
# x = 4.25
#
# Z-score:
# Z = (4.25 − 4) / 1 = 0.25
#
# This means **4.25 is 0.25 standard deviations above the mean**.
#
# ### Example 2
# x = 2.5
#
# Z-score:
# Z = (2.5 − 4) / 1 = −1.5
#
# This means **2.5 is 1.5 standard deviations below the mean**.
#
#
# ## 9️⃣ Why Standard Normal Distribution is Important
#
# - It allows comparison between **different datasets**
# - Removes unit dependency (kg, cm, ₹, etc.)
# - Makes data **scale-free**
#
#
# ## 🔟 Standardization (Feature Scaling)
# **Standardization** is the process of converting features so that they have: Mean = 0, Standard Deviation = 1
#
# Using:
# Z = (xᵢ − μ) / σ
#
#
# ## 1️⃣1️⃣ Example: Dataset Standardization
# | Feature | Values |
# |-------|--------|
# | Age (yrs) | 24, 25, 26, 27, 30 |
# | Weight (kg) | 70, 60, 55, 40, 30 |
# | Height (cm) | 175, 160, 180, 130 |
# | Salary (₹) | 40k, 50k, 60k, 30k |
#
# Each feature has **different scales**.
# Standardization converts them to a **common scale** using Z-score.
#
#
# ## 1️⃣2️⃣ Role of Z-Score in Machine Learning
# Standardization is required in many ML algorithms such as:
#
# 1. **Clustering Algorithms**
# 2. **Linear Regression**
# 3. **Logistic Regression**
# 4. **K-Nearest Neighbors**
# 5. **Support Vector Machines**
#
# It ensures that no feature dominates due to larger magnitude.
#
# ## Summary
# - Standard Normal Distribution has μ = 0 and σ = 1
# - Z-score measures distance from mean in standard deviations
# - Z-score formula: `(x − μ) / σ`
# - Standardization converts data to SND
# - Widely used in **statistics and machine learning**
