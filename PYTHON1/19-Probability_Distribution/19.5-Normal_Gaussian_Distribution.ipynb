# %% [markdown]
# # 📘 Normal (Gaussian) Distribution
#
# ## 1️⃣ Introduction to Normal (Gaussian) Distribution
# In probability theory and statistics, the **normal distribution** (also called the **Gaussian distribution**) is a **continuous probability distribution** for a real-valued random variable.
#
# It is widely used because many real-world phenomena naturally follow a normal pattern.
#
#
# ## 2️⃣ Nature of the Normal Distribution
#
# - It is a **continuous random variable**
# - It is represented by a **probability density function (PDF)**
# - The graph is a **bell-shaped curve**
# - The distribution is **symmetric about the mean**
# - **Mean = Median = Mode**
#
# ## 3️⃣ Examples of Normal Distribution
#
# Examples shown in the notes:
# - Weights of students in a class
# - Heights of students in a class
# - Iris dataset features (petal length, sepal length, petal width, sepal width)
# - Measurement errors in experiments
#
# These quantities vary continuously and cluster around a central value.
#
#
# ## 4️⃣ Normal Random Variable
#
# Let: X = a continuous random variable
#
# Then: X ∈ (−∞, +∞)
#
# ## 5️⃣ Parameters of Normal Distribution
#
# The normal distribution has **two parameters**:
#
# - **μ (mu)** → Mean
# - **σ² (sigma squared)** → Variance
#
# Notation:
# X ~ N(μ, σ²)
#
# Where:
# - μ ∈ ℝ
# - σ² > 0
#
# ## 6️⃣ Probability Density Function (PDF)
#
# The PDF of a normal distribution is given by:
#
# f(x) = (1 / (σ √(2π))) · e^{ −(1/2) ((x − μ)/σ)² }
#
# Where:
# - μ = mean
# - σ = standard deviation
# - e ≈ 2.718
#
#
# ## 7️⃣ Graphical Interpretation
# - The curve is **bell-shaped**
# - The highest point occurs at **x = μ**
# - As σ increases, the curve becomes **wider**
# - As σ decreases, the curve becomes **narrower**
#
# The **area under the curve** represents probability and is always **equal to 1**.
#
#
# ## 8️⃣ Mean of Normal Distribution
# The mean of a normal distribution is:
#
# μ = (Σ xᵢ) / n
#
# - It represents the **center** of the distribution
# - It divides the curve into two equal halves
#
#
# ## 9️⃣ Variance and Standard Deviation
# ### Variance:
# σ² = (Σ (xᵢ − μ)²) / n
#
# ### Standard Deviation:
# σ = √σ²
#
# - Variance measures **spread**
# - Standard deviation gives **average deviation from the mean**
#
#
# ## 🔟 Empirical Rule (68–95–99.7 Rule)
# For a normal distribution:
#
# - About **68%** of values lie within **μ ± σ**
# - About **95%** of values lie within **μ ± 2σ**
# - About **99.7%** of values lie within **μ ± 3σ**
#
# Written as probabilities:
#
# P(μ − σ ≤ X ≤ μ + σ) ≈ 68%
# P(μ − 2σ ≤ X ≤ μ + 2σ) ≈ 95%
# P(μ − 3σ ≤ X ≤ μ + 3σ) ≈ 99.7%
#
#
# ## 1️⃣1️⃣ QQ Plot (Quantile–Quantile Plot)
# - A **QQ plot** is used to check whether data follows a normal distribution
# - If the points lie approximately on a straight line, the data is **normally distributed**
# - Deviations from the line indicate skewness or outliers
#
# ## 1️⃣2️⃣ Important Properties
# - Continuous distribution
# - Symmetric about the mean
# - Mean = Median = Mode
# - Total area under the curve = 1
# - Defined over (−∞, +∞)
#
# ## 1️⃣3️⃣ Applications of Normal Distribution
# - Natural measurements (height, weight)
# - Errors in measurements
# - Standardized test scores
# - Finance and risk modeling
# - Machine learning (assumption in many models)
#
#
# ## Summary
# - Normal distribution is a **continuous probability distribution**
# - It is denoted as `N(μ, σ²)`
# - PDF is bell-shaped and symmetric
# - Mean, median, and mode are equal
# - Empirical rule explains data spread (68–95–99.7)
# - Widely used in **statistics, probability, and data science**
