# %% [markdown]
# # 📘 When to Use Z-Test vs t-Test
#
# ## 1️⃣ Purpose of This Decision Rule
# In hypothesis testing, choosing the **correct test** is very important.
# This decision rule helps us decide **whether to use a Z-test or a t-test** based on:
#
# - Knowledge of population standard deviation
# - Sample size
#
# The flowchart in the notes visually represents this decision-making process.
#
# ## 2️⃣ Step 1: Do You Know the Population Standard Deviation (σ)?
#
# The first and most important question is:
#
# Do you know the population standard deviation (σ)?
#
# yaml
# Copy code
#
# This question divides the decision into two cases.
#
# ## 3️⃣ Case 1: Population Standard Deviation (σ) is Known
#
# If the answer is **YES**, then move to the next question:
#
# Is the sample size greater than or equal to 30?
#
# ### Case 1(a): Sample Size ≥ 30
#
# If:
# σ is known
# and
# n ≥ 30
#
# Then:
#
# Use Z-test
#
# Reason:
# - Large sample size
# - Population variability is known
# - Sampling distribution of the mean follows normal distribution
#
# This path is shown on the **left-bottom side** of the diagram.
#
# ### Case 1(b): Sample Size < 30
#
# If:
# σ is known
# but
# n < 30
#
# Then:
#
# Use t-test
#
# Reason:
# - Small sample size
# - More uncertainty
# - t-distribution handles extra variability
#
# This is shown in the **left branch leading to t-test**.
#
# ## 4️⃣ Case 2: Population Standard Deviation (σ) is NOT Known
#
# If the answer to the first question is **NO**:
#
# σ is not known
#
# Then directly:
#
# Use t-test
#
# This is independent of sample size.
#
# Reason:
# - In real-world problems, σ is usually unknown
# - We replace σ with sample standard deviation (s)
# - This introduces extra uncertainty
# - t-distribution is designed for this situation
#
# This case is shown on the **right side of the diagram**.
#
# ## 5️⃣ Final Decision Logic (Text Form)
#
# The complete logic from the flowchart can be written as:
#
# If σ is known:
# - If n ≥ 30 → Use Z-test
# - If n < 30 → Use t-test
# - If σ is unknown:
#
#
# ## 6️⃣ Why This Rule is Important
#
# - Prevents wrong test selection
# - Ensures correct probability distribution is used
# - Avoids incorrect conclusions
# - Widely used in exams, statistics, and data science
#
#
# ## 7️⃣ Key Takeaway from the Diagram
#
# - **Z-test** is stricter and requires more information
# - **t-test** is flexible and used in most practical cases
# - Whenever in doubt and σ is unknown → **use t-test**
