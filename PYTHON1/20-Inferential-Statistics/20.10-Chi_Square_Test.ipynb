# %% [markdown]
# # 📘 Chi-Square (χ²) Test
#
# ## 1️⃣ Introduction to Chi-Square Test
#
# The **Chi-Square (χ²) test** is a **non-parametric statistical test** used to examine whether there is a **significant difference between observed data and expected data**.
#
# It is mainly used for:
# - **Categorical data**
# - **Frequency data**
# - Testing relationships or distributions
#
# ## 2️⃣ When is Chi-Square Test Used?
# The Chi-square test is used when:
# - Data is in the form of **counts or frequencies**
# - Variables are **categorical**
# - Sample size is reasonably large
# - Expected frequency in each category is preferably ≥ 5
#
# ## 3️⃣ Types of Chi-Square Tests
# There are mainly **two types**:
#
# 1. **Chi-Square Goodness of Fit Test**
# 2. **Chi-Square Test of Independence**
#
# ## 4️⃣ Chi-Square Test Statistic
# The chi-square test statistic is calculated using the formula:
#
# χ² = Σ [(Oᵢ − Eᵢ)² / Eᵢ]
#
# Where:
# - Oᵢ = observed frequency
# - Eᵢ = expected frequency
# - Σ = sum over all categories
#
# ## 5️⃣ Meaning of the Chi-Square Statistic
# - It measures the **difference between observed and expected frequencies**
# - Larger χ² value means **greater difference**
# - Smaller χ² value means **observed data is close to expected data**
#
# ## 6️⃣ Hypotheses in Chi-Square Test
# ### Null Hypothesis (H₀)
# There is no significant difference between observed and expected frequencies
#
# ### Alternative Hypothesis (H₁)
# There is a significant difference between observed and expected frequencies
#
# ## 7️⃣ Degree of Freedom (General)
# The degree of freedom depends on the type of chi-square test.
#
# For goodness of fit:
# df = k − 1
#
# Where:
# - k = number of categories
#
# ## 8️⃣ Decision Rule
# - Calculate χ² using the formula
# - Find critical χ² value from chi-square table
# - Compare:
#
# If χ²_calculated > χ²_critical → Reject H₀
# If χ²_calculated ≤ χ²_critical → Fail to reject H₀
#
# # 📘 Chi-Square Goodness of Fit Test
#
# ## 9️⃣ Introduction to Goodness of Fit
#
# The **Chi-Square Goodness of Fit Test** checks whether **sample data follows a specified theoretical distribution**.
#
# It tells us how well the **observed data fits the expected distribution**.
#
# ## 🔟 Purpose of Goodness of Fit Test
# Used to check if data follows:
# - Uniform distribution
# - Binomial distribution
# - Poisson distribution
# - Any given theoretical distribution
#
# ## 1️⃣1️⃣ Hypotheses for Goodness of Fit
# ### Null Hypothesis (H₀)
# The observed frequencies follow the expected distribution
#
# ### Alternative Hypothesis (H₁)
# The observed frequencies do not follow the expected distribution
#
# ## 1️⃣2️⃣ Steps in Chi-Square Goodness of Fit Test
# ### Step 1
# State H₀ and H₁
#
# ### Step 2
# Calculate expected frequencies (Eᵢ)
#
# ### Step 3
# Compute chi-square statistic:
# χ² = Σ [(Oᵢ − Eᵢ)² / Eᵢ]
#
# ### Step 4
# Find degree of freedom:
# df = k − 1
#
# ### Step 5
# Find critical value from chi-square table
#
# ### Step 6
# Make decision based on comparison
#
#
# ## 1️⃣3️⃣ Example (Conceptual)
#
# Suppose a dice is rolled many times.
#
# Expected frequency:
# Each face = Total throws / 6
#
# Observed frequency:
# Actual counts from experiment
#
# Apply chi-square formula to check if dice is **fair or biased**.
#
# ## 1️⃣4️⃣ Applications of Chi-Square Goodness of Fit
# - Checking fairness of dice or coins
# - Market research (customer preferences)
# - Genetics (phenotype distribution)
# - Quality control
# - Machine learning (feature distribution analysis)
#
# ## 1️⃣5️⃣ Important Points to Remember
# - Used for **categorical data**
# - Based on **frequencies**, not raw values
# - Sensitive to sample size
# - Expected frequencies should not be too small
# - Non-parametric test (no normality assumption)
