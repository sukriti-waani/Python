# %% [markdown]
# # 📘 Significance Level (α)
#
# ## 1️⃣ Definition of Significance Level
#
# The **significance level**, denoted by **α (alpha)**, is the **maximum probability of rejecting the null hypothesis (H₀) when it is actually true**.
#
# In simple words:
# - α is the **risk we are willing to take**
# - It represents the chance of making a **wrong decision**
#
# ## 2️⃣ Meaning of Significance Level
#
# The significance level decides:
# - How strong the evidence must be
# - To reject the null hypothesis
#
# A **smaller α** means:
# - Stricter testing
# - Less chance of rejecting H₀ incorrectly
#
#
# ## 3️⃣ Common Values of α
#
# Commonly used significance levels are:
# - α = 0.05 (5% significance level)
# - α = 0.01 (1% significance level)
# - α = 0.02 (2% significance level)
#
# - 95% confidence level → α = 0.05
# - 98% confidence level → α = 0.02
#
# ## 4️⃣ Relationship Between Confidence Level and α
#
# The relationship is:
# α = 1 − Confidence Level
#
# Examples:
# Confidence Level = 95% → α = 0.05
# Confidence Level = 98% → α = 0.02
#
# This relation is explicitly written in the notes.
#
# ## 5️⃣ Role of α in Decision Making
#
# The significance level **sets the decision boundary**.
#
# It divides the distribution into:
# - **Acceptance region**
# - **Rejection region**
#
# Only results falling in the rejection region lead to rejection of H₀.
#
# ## 6️⃣ α and Rejection Region (Two-Tailed Test)
#
# For a **two-tailed test** with:
# α = 0.05
#
# The rejection area is split as:
# 0.025 on the left tail
# 0.025 on the right tail
#
# Critical Z-values:
# −1.96 and +1.96
#
# This is shown clearly in the bell-curve diagram in the notes.
#
# ## 7️⃣ α and Rejection Region (One-Tailed Test)
#
# For a **one-tailed test**:
# - Entire α is placed on **one side** of the distribution
#
# Example from notes:
# α = 0.02
#
# Rejection region lies entirely in:
# - Left tail (or right tail depending on H₁)
#
# ## 8️⃣ Decision Rule Using α
#
# The rule is:
# - If p-value ≤ α → Reject H₀
# - If p-value > α → Fail to reject H₀
#
# This comparison is explicitly done in both numerical examples in the notes.
#
# ## 9️⃣ Important Points About Significance Level
# - α is chosen **before testing**
# - It is not calculated from data
# - Smaller α → stronger evidence required
# - Controls the probability of **Type I error**
#
#
# # 📘 Z-Test
# ## 1️⃣ What is a Z-Test?
#
# A **Z-test** is a **statistical hypothesis test** used to determine whether the **sample mean** is significantly different from the **population mean**.
#
# It is based on the **standard normal distribution (Z-distribution)**.
#
# ## 2️⃣ When Do We Use a Z-Test?
#
# A Z-test is used when **all the following conditions are satisfied**:
#
# - Population standard deviation **σ is known**
# - Sample size is **large (n ≥ 30)**
# - The population distribution is **normal**
#   OR
#   Sample size is large enough to apply **Central Limit Theorem**
#
# These conditions are clearly indicated in your notes.
#
#
# ## 3️⃣ Purpose of Z-Test
#
# The Z-test helps us to:
# - Decide whether to **reject or not reject H₀**
# - Check if the observed sample mean is due to **random chance**
# - Test claims about the **population mean**
#
# ## 4️⃣ Z-Test Statistic
#
# The **Z-test statistic** is calculated using the formula:
#
# Z = (x̄ − μ) / (σ / √n)
#
# Where:
# - x̄ = sample mean
# - μ = population mean (from H₀)
# - σ = population standard deviation
# - n = sample size
#
# This formula standardizes the sample mean.
#
#
# ## 5️⃣ Meaning of Z-Score in Z-Test
#
# The Z-value tells us:
# - How many **standard errors** the sample mean is away from the population mean
# - How far the sample result is from what is expected under H₀
#
# A large |Z| value indicates strong evidence against H₀.
#
#
# ## 6️⃣ Types of Z-Test
#
# ### (i) Two-Tailed Z-Test
# Used when:
# H₁ : μ ≠ μ₀
#
# Rejection region lies on **both sides** of the distribution.
#
# ### (ii) Right-Tailed Z-Test
# Used when:
# H₁ : μ > μ₀
#
# Rejection region lies on the **right side**.
#
#
# ### (iii) Left-Tailed Z-Test
# Used when:
# H₁ : μ < μ₀
#
# Rejection region lies on the **left side**.
#
# ## 7️⃣ Decision Rule Using Z-Test
#
# There are **two equivalent methods**:
#
# ### Method 1: Critical Value Approach
# - If |Z| > Z_critical → Reject H₀
# - If |Z| ≤ Z_critical → Fail to reject H₀
#
# ### Method 2: P-Value Approach
# If p-value ≤ α → Reject H₀
# If p-value > α → Fail to reject H₀
#
# ## 8️⃣ Common Critical Z-Values
# For commonly used significance levels:
#
# α = 0.05 (two-tailed) → Z = ±1.96
# α = 0.01 (two-tailed) → Z = ±2.58.
#
# ## 9️⃣ Interpretation of Z-Test Result
# - If H₀ is rejected → sample evidence supports H₁
# - If H₀ is not rejected → insufficient evidence against H₀
# - Rejection does **not prove H₁ true**, it only shows strong evidence
#
#
# ## 🔟 Important Points About Z-Test
# - Used only when σ is known
# - Suitable for large samples
# - Based on normal distribution
# - Widely used in quality control and research
