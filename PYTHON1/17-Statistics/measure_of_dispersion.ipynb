# %% [markdown]
# ### 📊 Measure of Dispersion :
# A measure of dispersion is a statistical measure that describes how spread out or scattered the data values are around the mean.
#
# #### 1️⃣ Variance
# Variance is the average of the squared deviations of each observation from the mean.
#
# - Population Variance
# σ² = (1 / N) * Σ (xᵢ − μ)²
#
# - Sample Variance
# s² = (1 / (n − 1)) * Σ (xᵢ − x̄)²
#
#
# #### 2️⃣ Standard Deviation
# Standard Deviation is the positive square root of variance and indicates average deviation of data from the mean.
#
# - Population Standard Deviation
# 	σ = √[(1 / N) * Σ (xᵢ − μ)²]
#
# - Sample Standard Deviation
# 	s = √[(1 / (n − 1)) * Σ (xᵢ − x̄)²]
#
# where:
# xᵢ  = i-th observation
# μ   = population mean
# x̄   = sample mean
# N   = population size
# n   = sample size
# Σ   = summation
#
# - Relationship
#   Standard deviation is the square root of variance.
#
# 📝 In short:
# Variance measures spread using squared deviations
# Standard deviation measures actual spread in same unit as data
#
#
# #### ❓ Why We Use Measures of Dispersion
# - Measures of dispersion are used to know how much data values vary around the mean.
# - Mean alone cannot show data spread
# - Helps compare datasets
# - Shows consistency or variability
# - Indicates risk and uncertainty
# - Important in statistics and machine learning
# - Variance measures squared spread mathematically.
# Standard Deviation shows actual spread in the same unit as data, so it is easier to understand.

# %% [markdown]
# ## 📌 Bessel’s Correction
# Bessel’s correction is a statistical adjustment in which we divide by (n − 1) instead of n when calculating sample variance.
#
# It is used only for sample variance, not for population variance.
#
# #### ❓ Why Do We Need Bessel’s Correction?
# - When we calculate variance from a sample, we first compute the sample mean (x̄).
# - This sample mean is estimated from the same data, so the data points are slightly closer to x̄ than they would be to the true population mean (μ).
#
# ##### ✅ As a result:
# - Squared deviations become smaller
# - Variance calculated using n becomes underestimated
#
# #### 🔑 Role of (n − 1) – Degrees of Freedom
# After calculating the sample mean, only (n − 1) values are free to vary
#
# The last value is fixed because the sum of deviations from the mean must be zero
#
# Therefore:
# Degrees of Freedom = n − 1
#
#
# Using (n − 1) compensates for the lost degree of freedom.
#
# #### ✅ Formula with Bessel’s Correction
# Sample Variance:
# s² = (1 / (n − 1)) Σ (xᵢ − x̄)²
#
# 🔍 Simple Example
#
# Suppose we take a small sample from a population.
#
# Because the sample is small, using n makes variance too small
#
# Dividing by (n − 1) slightly increases variance
#
# This gives a better estimate of true population variance
#
# ✅ When to Use What?
# Situation	Denominator
# Population data	N
# Sample data	n − 1
#
#
# #### 📝 Summary
#
# Bessel’s correction is used while computing sample variance to avoid underestimation. Since the sample mean is used, one degree of freedom is lost. Dividing by (n − 1) instead of n provides an unbiased estimate of population variance.

# %% [markdown]
# ## 📊 Population (Statistics)
#
# - | Aspect | Population |
# - |------|-----------|
# - | Definition | Entire group of data under study |
# - | Mean Formula | μ = (Σxᵢ) / N |
# - | Variance Symbol | σ² |
# - | Variance Formula | σ² = (1 / N) Σ(xᵢ − μ)² |
# - | Standard Deviation Symbol | σ |
# - | Standard Deviation Formula | σ = √[(1 / N) Σ(xᵢ − μ)²] |
# - | Correction | No correction required |
# - | Nature of Result | Exact value |
# - | Usage | Used when full population data is available |

# %% [markdown]
# ## 📊 Sample (Statistics)
#
# - | Aspect | Sample |
# - |------|--------|
# - | Definition | Subset taken from the population |
# - | Size Symbol | n |
# - | Mean Symbol | x̄ |
# - | Mean Formula | x̄ = (Σxᵢ) / n |
# - | Variance Symbol | s² |
# - | Variance Formula | s² = (1 / (n − 1)) Σ(xᵢ − x̄)² |
# - | Standard Deviation Symbol | s |
# - | Standard Deviation Formula | s = √[(1 / (n − 1)) Σ(xᵢ − x̄)²] |
# - | Correction Used | Bessel’s correction (n − 1) |
# - | Nature of Result | Estimated value |
# - | Usage | Used when population data is large or unknown |
