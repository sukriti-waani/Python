# %% [markdown]
# # 📊 Covariance and Correlation (Complete Explained Notes)
#
# Covariance and correlation are statistical measures used to determine the **relationship between two variables**.
# They help us understand **how changes in one variable are associated with changes in another variable**.
#
#
# ## Relationship Between Variables
# A relationship between variables exists when a change in one variable **causes or is associated with a change in another variable**.
#
# Example:
# - If study hours increase and exam score increases, the variables are related.
#
#
# ## 1️⃣ Covariance
#
# ### Definition
# Covariance is a statistical measure that indicates **the direction of the relationship between two variables** by showing how they change together.
#
#
# ### Interpretation of Covariance
#
# | Change in X | Change in Y | Covariance |
# |------------|------------|-----------|
# | Increases | Increases | Positive |
# | Decreases | Decreases | Positive |
# | Increases | Decreases | Negative |
# | Decreases | Increases | Negative |
#
# - If both variables move in the same direction → **Positive covariance**
# - If variables move in opposite directions → **Negative covariance**
#
# 📌 Covariance only shows **direction**, not strength.
#
#
# ### Intuition Examples
# - Size of house ↑ → Price ↑ → Positive covariance
# - Distance from city ↑ → Price ↓ → Negative covariance
#
# Covariance helps **quantify the relationship between X and Y**.
#
#
# ### Covariance Formula (Sample)
#
# Covariance between X and Y is given by:
# Cov(X,Y) = Σ (xᵢ − x̄)(yᵢ − ȳ) / (n − 1)
#
# Where:
#
# xᵢ = ith data point of variable X
#
# yᵢ = ith data point of variable Y
#
# x̄ = mean of X
#
# ȳ = mean of Y
#
# n = number of observations
#
# ✅ Important Property of Covariance
# Cov(X, X) = Var(X)
#
# Statement:
# The covariance of a variable with itself is equal to its variance.
#
# ### ❌ Limitations of Covariance
#
# Covariance has no fixed range
#
# Values lie between −∞ and +∞
#
# Units depend on the data
#
# Difficult to compare relationships across datasets
#
# 📌 To overcome these problems, correlation is used.

# %% [markdown]
# ## 2 Correlation
# Correlation is a statistical measure that indicates both the direction and the strength of the relationship between two variables.
#
# Correlation is a standardized form of covariance.
#
# #### Sample Covariance Formula
#
# Cov(X, Y) = Σ (xᵢ − x̄)(yᵢ − ȳ) / (n − 1)
#
# ### Pearson Correlation Coefficient
# The Pearson correlation coefficient measures the linear relationship between two variables.
#
# r = Cov(X, Y) / (σₓ · σᵧ)
#
# Expanded Pearson Correlation Formula
#
# r = [Σ (xᵢ − x̄)(yᵢ − ȳ)]
#     / √[Σ (xᵢ − x̄)² · Σ (yᵢ − ȳ)²]
#
# Where:
# - σₓ = standard deviation of X
# - σᵧ = standard deviation of Y
# - Range of Pearson Correlation : -1 ≤ r ≤ +1
#
# #### Interpretation of r
# - r = +1	Perfect positive linear relationship
# - r = 0	No linear relationship
# - r = −1	Perfect negative linear relationship
#
# - As r → +1 → stronger positive correlation
# - As r → −1 → stronger negative correlation
#
# ##### Statement
#
# Values closer to +1 indicate strong positive correlation
#
# Values closer to −1 indicate strong negative correlation
#
# ### Spearman Rank Correlation
# Spearman rank correlation measures the monotonic relationship between two variables using their ranks instead of actual values.
#
# (Rank Difference Formula)
# - ρ = 1 − [6 Σ dᵢ² / n(n² − 1)]
#
#
# Spearman Rank Correlation Coefficient
# - ρ = Cov(R(X), R(Y)) / (σ(R(X)) · σ(R(Y)))
#
# Where:
#
# R(X) = rank of X
#
# R(Y) = rank of Y
#
# #### When to Use Spearman Correlation
# - Relationship is non-linear
# - Data is ranked or ordinal
# - Dataset contains outliers
#
# #### Relationship Between Covariance and Correlation
#
# Corr(X, Y) = Cov(X, Y) / (σₓ · σᵧ)
#
#
# #### Role of Correlation in Machine Learning (Feature Selection)
# - Correlation is used in feature selection to remove redundant features.
# - Highly correlated features carry similar information
# - One of the correlated features can be removed
# - This improves model efficiency and performance
#
# Example:
#
# Size of house ↑ → Price ↑ (positive correlation)
#
# Number of rooms ↑ → Size ↑ (high correlation)
#
# One feature may be removed to avoid duplication.
