# %% [markdown]
# ## Variable
# A variable is a property or characteristic that can take different values.
#
# In simple words, anything that changes or varies is called a variable.
#
# Examples
#
# Age = 25
#
# Gender = Male
#
# Height = 172 cm
#
# Here, age, gender, and height are variables.
#
# ####  Types of Variables
#
# Variables are mainly divided into two types:
#
# 🔹 1. Quantitative Variable
#
# Quantitative variables are numerical values that can be measured or counted.
#
# They are further divided into:
#
# - (a) Discrete Quantitative Variable
#
# Takes countable values
#
# Values are usually whole numbers
#
# Examples:
#
# Number of students in a class
#
# Number of children in a family
#
# Tossing a coin (0 or 1)
#
# - (b) Continuous Quantitative Variable
#
# Takes measurable values
#
# Can have decimal values
#
# Examples:
#
# Height (175.5 cm)
#
# Weight (72.7 kg)
#
# Temperature
#
# 🔹 2. Qualitative (Categorical) Variable
#
# Qualitative variables describe qualities or categories, not numbers.
#
# Examples:
#
# Gender → Male / Female
#
# Colors → Red, Green, Blue
#
# Blood group
#
# ## Random Variable
# A random variable is a function that assigns numerical values to the outcomes of a random experiment.
#
#  It converts outcomes into numbers.
#
# Examples
# Example 1: Tossing a Coin
#
# Let,
#
# X = 0 → Head
# X = 1 → Tail
#
#
# Here, X is a random variable.
#
# Example 2: Rolling a Fair Dice
# X = {1, 2, 3, 4, 5, 6}
#
#
# Each outcome is assigned a numeric value.
#
# Example 3: Height of people attending an event
#
# Possible values:
#
# 160 cm, 165 cm, 170.5 cm, ...
#
#
# This is also a random variable.
#
# ### Types of Random Variables
#
# Random variables are of two types:
#
# 🔹 1. Discrete Random Variable
#
# A discrete random variable takes finite or countable values.
#
#  Examples:
#
# Tossing a coin
#
# Rolling a dice
#
# Number of students present
#
# 🔹 2. Continuous Random Variable
#
# A continuous random variable takes infinite values within a range.
#
#  Examples:
#
# Amount of rainfall tomorrow
#
# Height of a person
#
# Weight of students
#
# #### Quick  Summary
# - A variable is a changing quantity
#
# - Variables can be quantitative or qualitative
# - A random variable assigns numbers to outcomes
# - Discrete random variables are countable
# - Continuous random variables are measurable

# %% [markdown]
# ## 5️⃣ Difference Between Discrete and Continuous Random Variable
#
# | Aspect | Discrete Random Variable | Continuous Random Variable |
# |--------|---------------------------|-----------------------------|
# | Values | Countable | Measurable |
# | Nature | Fixed values | Infinite values |
# | Examples | Dice, coin toss | Height, weight |
# | Output | Integer values | Decimal values |

# %% [markdown]
# ## 📊 Histograms
#
# ### ✅ What is a Histogram?
# A histogram is a plot that shows how often values occur in different intervals (called **bins**).
# It is mainly used for **continuous numerical data** such as age, height, or weight.
#
# ### 📌 Example Data
# X = {23, 24, 25, 30, 34, 36, 40, 50, 60, 75, 80}
#
# ### 📌 Bins and Frequencies
# - 20–30 → 4
# - 30–40 → 3
# - 40–50 → 1
# - 50–60 → 1
# - 60–70 → 0
# - 70–80 → 2
#
# These bars create the histogram.
#
# ### 📌 What are Bins?
# Bins are the continuous ranges used to group data values.
# Example bins: 20–30, 30–40, 40–50, etc.
#
#
# ### 📈 What Histogram Shows
# - High bar = more values in that range
# - Low bar = fewer values
# - Overall shape of distribution (skewness, symmetry, peaks)
#
#
# ### KDE (Kernel Density Estimation)
# KDE is a smooth curve drawn over the histogram.
# It helps show the distribution more clearly by “smoothening” the histogram.
