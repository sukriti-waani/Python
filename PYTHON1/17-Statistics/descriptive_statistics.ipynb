# %% [markdown]
# ## 📊 Percentiles, Quartiles, and 5-Number Summary
#
# ### Percentile
# A percentile is a value below which a certain percentage of observations fall.
#
# **Percentile Rank Formula:**
# Percentile of x = (# of values below x / n) × 100
#
# **Value at Percentile p:**
# Value = (p / 100) × (n + 1)
#
# ### Quartiles
# Quartiles split data into 4 equal parts:
#
# - Q1 = 25th percentile
# - Q2 = 50th percentile (median)
# - Q3 = 75th percentile
#
# **IQR (Interquartile Range):**
# IQR = Q3 − Q1
#
#
# ### 5-Number Summary
# 1. Minimum
# 2. Q1
# 3. Median
# 4. Q3
# 5. Maximum
#
#
# ### Outlier Detection (Fences)
# Lower Fence = Q1 − 1.5(IQR)
# Upper Fence = Q3 + 1.5(IQR)
#
# Values outside these fences are **outliers**.
#
#
# ### Box Plot
# - Minimum → left whisker
# - Q1 → left box edge
# - Median → middle line
# - Q3 → right box edge
# - Maximum → right whisker
# - Outliers → points outside whiskers
